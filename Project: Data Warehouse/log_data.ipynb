# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Owner'

# %%
os.chdir('C://Users//Owner/Desktop/')

# %%
log_data_df = pd.read_csv('log_data.csv')

# %%
log_data_df.head()
# Out:
#     artist       auth firstName gender  itemInSession lastName     length  \
# 0      NaN  Logged In    Walter      M              0     Frye        NaN
# 1      NaN  Logged In    Kaylee      F              0  Summers        NaN
# 2  Des'ree  Logged In    Kaylee      F              1  Summers  246.30812
# 3      NaN  Logged In    Kaylee      F              2  Summers        NaN
# 4  Mr Oizo  Logged In    Kaylee      F              3  Summers  144.03873
#
#   level                           location method      page  registration  \
# 0  free  San Francisco-Oakland-Hayward, CA    GET      Home  1.540919e+12
# 1  free        Phoenix-Mesa-Scottsdale, AZ    GET      Home  1.540345e+12
# 2  free        Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong  1.540345e+12
# 3  free        Phoenix-Mesa-Scottsdale, AZ    GET   Upgrade  1.540345e+12
# 4  free        Phoenix-Mesa-Scottsdale, AZ    PUT  NextSong  1.540345e+12
#
#    sessionId          song  status             ts  \
# ...

# %%
log_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8056 entries, 0 to 8055
# Data columns (total 18 columns):
# artist           6820 non-null object
# auth             8056 non-null object
# firstName        7770 non-null object
# gender           7770 non-null object
# itemInSession    8056 non-null int64
# lastName         7770 non-null object
# length           6820 non-null float64
# level            8056 non-null object
# location         7770 non-null object
# method           8056 non-null object
# page             8056 non-null object
# registration     7770 non-null float64
# sessionId        8056 non-null int64
# song             6820 non-null object
# status           8056 non-null int64
# ts               8056 non-null int64
# userAgent        7770 non-null object
# userId           7770 non-null float64
# dtypes: float64(3), int64(4), object(11)
# memory usage: 1.1+ MB

# %%
sns.heatmap(log_data_df.isnull(), yticklabels= False, cbar = False, cmap = 'viridis')

# %%
log_data_df.describe(include =[np.number]).T
# Out:
#                 count          mean           std           min           25%  \
# itemInSession  8056.0  2.119886e+01  2.344070e+01  0.000000e+00  3.000000e+00
# length         6820.0  2.470322e+02  1.029759e+02  1.585587e+01  1.973220e+02
# registration   7770.0  1.540778e+12  2.651572e+08  1.539909e+12  1.540558e+12
# sessionId      8056.0  5.981676e+02  2.853131e+02  3.000000e+00  3.720000e+02
# status         8056.0  2.028976e+02  1.799426e+01  2.000000e+02  2.000000e+02
# ts             8056.0  1.542486e+12  7.003166e+08  1.541106e+12  1.542023e+12
# userId         7770.0  5.446396e+01  2.816850e+01  2.000000e+00  2.900000e+01
#
#                         50%           75%           max
# itemInSession  1.300000e+01  3.300000e+01  1.270000e+02
# length         2.329726e+02  2.741220e+02  2.594873e+03
# registration   1.540829e+12  1.541020e+12  1.541098e+12
# sessionId      6.050000e+02  8.340000e+02  1.114000e+03
# status         2.000000e+02  2.000000e+02  4.040000e+02
# ...

# %%
log_data_df.describe(include = [np.object, pd.Categorical]).T
# Out:
#           count unique                                                top  \
# artist     6820   3148                                           Coldplay
# auth       8056      2                                          Logged In
# firstName  7770     85                                              Chloe
# gender     7770      2                                                  F
# lastName   7770     87                                             Cuevas
# level      8056      2                                               paid
# location   7770     63                  San Francisco-Oakland-Hayward, CA
# method     8056      2                                                PUT
# page       8056     13                                           NextSong
# song       6820   5189                                     You're The One
# userAgent  7770     40  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
#
#            freq
# artist       58
# auth       7770
# firstName   791
# ...
